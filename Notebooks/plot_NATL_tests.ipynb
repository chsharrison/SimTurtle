# %%
# plot NATL test
# 56 particles were released on 1-6-0001 and run for 12 days
# some of these were released on land, need to see what happens

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc
import os

# %%
# make default figure size 2x bigger, can toggle this
import matplotlib
matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi']

# %%
# get output data

nexpt = "FL"
npath = '/glade/p/work/chsharri/Cms-master/expt/' + nexpt + '/expt_' + nexpt + '/output/'
nfile = 'traj_file_1.nc'
cmsdata = nc.Dataset(npath+nfile,'r')

# %%
plon = cmsdata.variables['lon'][:]
plat = cmsdata.variables['lat'][:]
plon.shape
# Out:
# (1344, 25)

# %%
# get subsetted data from cms 

path = '/glade/p/work/chsharri/Cms-master/expt/' + nexpt + '/expt_' + nexpt + '/nests/'
date = "10105"
myfile = 'nest_1_000' + date + '000000.nc' 

mydata = nc.Dataset(path+myfile,'r')
lon = mydata.variables['Longitude'][:]
lat = mydata.variables['Latitude'][:]
u = mydata.variables['zu'][0,0,:,:]
v = mydata.variables['zv'][0,0,:,:]

sst = mydata.variables['zt'][0,0,:,:]

# %%
print sst.shape
print lat.shape
# Out:
# (165, 121)
# (165,)

# %%
plt.pcolormesh(lon, lat, sst, vmin = 20, vmax = 30)
plt.axis([lon.min(), lon.max(), lat.min(), lat.max()])
cb1 = plt.colorbar()
# different time of year than previous plot(winter)

plt.plot(plon[:,0], plat[:,0],'k.')

plt.axes().set_aspect('equal')
plt.title(date)
plt.xlabel('Lon')
plt.ylabel('Lat')

# %%
plt.pcolormesh(lon, lat, sst, vmin = 20, vmax = 30)
plt.axis([lon.min(), lon.max(), lat.min(), lat.max()])
cb1 = plt.colorbar()
# different time of year than previous plot(winter)

plt.plot(plon[:,5], plat[:,5],'k.')

plt.axes().set_aspect('equal')
plt.title(date)
plt.xlabel('Lon')
plt.ylabel('Lat')

# %%
# get subsetted data from cms 

path = '/glade/p/work/chsharri/Cms-master/expt/' + nexpt + '/expt_' + nexpt + '/nests/'
date = "10110"
myfile = 'nest_1_000' + date + '000000.nc' 

mydata = nc.Dataset(path+myfile,'r')
sst2 = mydata.variables['zt'][0,0,:,:]

# %%
# last timestep:
plt.pcolormesh(lon, lat, sst2, vmin = 20, vmax = 30)
plt.axis([lon.min(), lon.max(), lat.min(), lat.max()])
cb1 = plt.colorbar()
# different time of year than previous plot(winter)

plt.plot(plon[:,10], plat[:,10],'k.')

plt.axes().set_aspect('equal')
plt.title(date)
plt.xlabel('Lon')
plt.ylabel('Lat')

# %%
# last timestep:
plt.pcolormesh(lon, lat, sst2, vmin = 20, vmax = 30)
plt.axis([lon.min(), lon.max(), lat.min(), lat.max()])
cb1 = plt.colorbar()
# different time of year than previous plot(winter)

plt.plot(plon[:,-2], plat[:,-2],'k.')

plt.axes().set_aspect('equal')
plt.title(date)
plt.xlabel('Lon')
plt.ylabel('Lat')

# %% [markdown]
# # NATL test

# %%
# now for next experiment: NATL
# files are written in chunks to to each proccessor, so there are 5 particle files

# get output data

nexpt = "NATL"
npath = '/glade/p/work/chsharri/Cms-master/expt/' + nexpt + '/expt_' + nexpt + '/output/'

# need to make a loop here
nfiles = 5


nfile = 'traj_file_1.nc'
cmsdata = nc.Dataset(npath+nfile,'r')
plon = cmsdata.variables['lon'][:]
plat = cmsdata.variables['lat'][:]
plon.shape


nfile2 = 'traj_file_2.nc'
cmsdata2 = nc.Dataset(npath+nfile2,'r')
plon2 = cmsdata2.variables['lon'][:]
plat2 = cmsdata2.variables['lat'][:]

nfile3 = 'traj_file_3.nc'
cmsdata3 = nc.Dataset(npath+nfile3,'r')
plon3 = cmsdata3.variables['lon'][:]
plat3 = cmsdata3.variables['lat'][:]

nfile4 = 'traj_file_4.nc'
cmsdata4 = nc.Dataset(npath+nfile4,'r')
plon4 = cmsdata4.variables['lon'][:]
plat4 = cmsdata4.variables['lat'][:]

nfile5 = 'traj_file_5.nc'
cmsdata5 = nc.Dataset(npath+nfile5,'r')
plon5 = cmsdata5.variables['lon'][:]
plat5 = cmsdata5.variables['lat'][:]

# %%
ptest = np.concatenate((plat, plat2), axis = 0)
ptest.shape
# Out:
# (13530, 61)

# %%
# get the particles in a loop, are these in the same organization as write file? Compare with that script

nexpt = "NATL"
npath = '/glade/p/work/chsharri/Cms-master/expt/' + nexpt + '/expt_' + nexpt + '/output/'

# need to make a loop here
nfiles = 5

nfile = 'traj_file_1.nc'
cmsdata = nc.Dataset(npath+nfile,'r')
plon = cmsdata.variables['lon'][:]
plat = cmsdata.variables['lat'][:]

for ifile in range(2,nfiles+1):
    nfile = 'traj_file_'+str(ifile)+ '.nc'
    cmsdata = nc.Dataset(npath+nfile,'r')
    plon = np.concatenate((plon,cmsdata.variables['lon'][:]), axis = 0)
    plat = np.concatenate((plat,cmsdata.variables['lat'][:]), axis = 0)

plat.shape
# Out:
# (33824, 61)

# %%
# get subsetted data from cms 

path = '/glade/p/work/chsharri/Cms-master/expt/' + nexpt + '/expt_' + nexpt + '/nests/'
date = "10105"
myfile = 'nest_1_000' + date + '000000.nc' 

mydata = nc.Dataset(path+myfile,'r')
lon = mydata.variables['Longitude'][:]
lat = mydata.variables['Latitude'][:]
u = mydata.variables['zu'][0,0,:,:]
v = mydata.variables['zv'][0,0,:,:]

sst = mydata.variables['zt'][0,0,:,:]

# %%
print sst.shape
print lat.shape
# Out:
# (190, 621)
# (190,)

# %%
plt.pcolormesh(lon, lat, sst, vmin = 20, vmax = 30)
plt.axis([lon.min(), 315, lat.min(), lat.max()])
cb1 = plt.colorbar(orientation='horizontal')
# different time of year than previous plot(winter)

plt.plot(plon[:,0], plat[:,0],'k.', markersize = 1)

plt.axes().set_aspect('equal')
plt.title(date)
plt.xlabel('Lon')
plt.ylabel('Lat')

# %%
plt.pcolormesh(lon, lat, sst, vmin = 20, vmax = 30)
plt.axis([lon.min(),315, lat.min(), lat.max()])
cb1 = plt.colorbar(orientation='horizontal')

# different time of year than previous plot(winter)

i = 5

plt.plot(plon[:,i], plat[:,i],'k.', markersize = 1)
plt.plot(plon2[:,i], plat2[:,i],'k.', markersize = 1)
plt.plot(plon3[:,i], plat3[:,i],'k.', markersize = 1)
plt.plot(plon4[:,i], plat4[:,i],'k.', markersize = 1)
plt.plot(plon5[:,i], plat5[:,i],'k.', markersize = 1)

plt.axes().set_aspect('equal')
plt.title(date)
plt.xlabel('Lon')
plt.ylabel('Lat')

# %%
# get subsetted data from cms 

path = '/glade/p/work/chsharri/Cms-master/expt/' + nexpt + '/expt_' + nexpt + '/nests/'
date = "10110"
myfile = 'nest_1_000' + date + '000000.nc' 

mydata = nc.Dataset(path+myfile,'r')

u2 = mydata.variables['zu'][0,0,:,:]
v2 = mydata.variables['zv'][0,0,:,:]

sst2 = mydata.variables['zt'][0,0,:,:]

# %%
plt.pcolormesh(lon, lat, sst2, vmin = 20, vmax = 30)
plt.axis([lon.min(),315, lat.min(), lat.max()])
cb1 = plt.colorbar(orientation='horizontal')

# different time of year than previous plot(winter)

i = 5

plt.plot(plon[:,i], plat[:,i],'k.', markersize = 1)
plt.plot(plon2[:,i], plat2[:,i],'k.', markersize = 1)
plt.plot(plon3[:,i], plat3[:,i],'k.', markersize = 1)
plt.plot(plon4[:,i], plat4[:,i],'k.', markersize = 1)
plt.plot(plon5[:,i], plat5[:,i],'k.', markersize = 1)

plt.axes().set_aspect('equal')
plt.title(date)
plt.xlabel('Lon')
plt.ylabel('Lat')

# %%
# get subsetted data from cms 

path = '/glade/p/work/chsharri/Cms-master/expt/' + nexpt + '/expt_' + nexpt + '/nests/'
date = "10120"
myfile = 'nest_1_000' + date + '000000.nc' 

mydata = nc.Dataset(path+myfile,'r')

sst = mydata.variables['zt'][0,0,:,:]

plt.pcolormesh(lon, lat, sst, vmin = 20, vmax = 30)
plt.axis([lon.min(),315, lat.min(), lat.max()])
cb1 = plt.colorbar(orientation='horizontal')

# different time of year than previous plot(winter)

i = 15

plt.plot(plon[:,i], plat[:,i],'k.', markersize = 1)
plt.plot(plon2[:,i], plat2[:,i],'k.', markersize = 1)
plt.plot(plon3[:,i], plat3[:,i],'k.', markersize = 1)
plt.plot(plon4[:,i], plat4[:,i],'k.', markersize = 1)
plt.plot(plon5[:,i], plat5[:,i],'k.', markersize = 1)

plt.axes().set_aspect('equal')
plt.title(date)
plt.xlabel('Lon')
plt.ylabel('Lat')

# %%
# get subsetted data from cms 

path = '/glade/p/work/chsharri/Cms-master/expt/' + nexpt + '/expt_' + nexpt + '/nests/'
date = "10130"
myfile = 'nest_1_000' + date + '000000.nc' 

mydata = nc.Dataset(path+myfile,'r')

sst = mydata.variables['zt'][0,0,:,:]

plt.pcolormesh(lon, lat, sst, vmin = 20, vmax = 30)
plt.axis([lon.min(),315, lat.min(), lat.max()])
cb1 = plt.colorbar(orientation='horizontal')

# different time of year than previous plot(winter)

i = 25

plt.plot(plon[:,i], plat[:,i],'k.', markersize = 1)
plt.plot(plon2[:,i], plat2[:,i],'k.', markersize = 1)
plt.plot(plon3[:,i], plat3[:,i],'k.', markersize = 1)
plt.plot(plon4[:,i], plat4[:,i],'k.', markersize = 1)
plt.plot(plon5[:,i], plat5[:,i],'k.', markersize = 1)

plt.axes().set_aspect('equal')
plt.title(date)
plt.xlabel('Lon')
plt.ylabel('Lat')

# %%
# get subsetted data from cms 

path = '/glade/p/work/chsharri/Cms-master/expt/' + nexpt + '/expt_' + nexpt + '/nests/'
date = "10306"
myfile = 'nest_1_000' + date + '000000.nc' 

mydata = nc.Dataset(path+myfile,'r')

sst = mydata.variables['zt'][0,0,:,:]

plt.pcolormesh(lon, lat, sst, vmin = 20, vmax = 30)
plt.axis([lon.min(),315, lat.min(), lat.max()])
cb1 = plt.colorbar(orientation='horizontal')

# different time of year than previous plot(winter)

i = 60

plt.plot(plon[:,i], plat[:,i],'k.', markersize = 1)
plt.plot(plon2[:,i], plat2[:,i],'k.', markersize = 1)
plt.plot(plon3[:,i], plat3[:,i],'k.', markersize = 1)
plt.plot(plon4[:,i], plat4[:,i],'k.', markersize = 1)
plt.plot(plon5[:,i], plat5[:,i],'k.', markersize = 1)

plt.axes().set_aspect('equal')
plt.title(date)
plt.xlabel('Lon')
plt.ylabel('Lat')

# %%
# does release date work well with python
# need to convert julian date
import jdcal

# %%
test = sum(jdcal.gcal2jd(1,1,6))+0.5

# %%
print test
# Out:
# 1721431.0

# %%
jdcal.jd2gcal?

# %%
test2 = jdcal.jd2gcal(0, 1721431-0.5)
print test2
# Out:
# (1, 1, 6, 0.0)

# %%
test2?

# %%
str(test2[0:3])
# Out:
# '(1, 1, 6)'

# %%
test3= str(test2[0])+'-'+str(test2[1])+'-'+str(test2[2])

# %%
print test3
# Out:
# 1-1-6

# %%
rtime = cmsdata.variables['releasedate'][:]

# %%
rtime
# Out:
# array([ 1721431.,  1721431.,  1721431., ...,  1721431.,  1721431.,
#         1721431.])

# %%
begintime = jdcal.jd2gcal(0, rtime.min()-0.5)
print begintime
# Out:
# (1, 1, 6, 0.0)

# %%
test = int(begintime[0])

# %%
test?

# %%
yr = int(begintime[0])
mo = int(begintime[1])
day = int(begintime[2])

# %%
print yr, mo, day
# Out:
# 1 1 6

# %%
if (mo<10):
    mm = '0'+str(mo)
else: 
    mm = str(mo)

# %%
print mm
# Out:
# 01

# %%
yr = int(begintime[0])
mo = int(begintime[1])
day = int(begintime[2])
if (mo<10):
	mm = '0'+str(mo)
else: mm = str(mo)
if (day<10):
	dd = '0'+str(day)
else: dd = str(day)
date = str(yr)+mm+dd

# %%
print date
# Out:
# 10106

# %%
#
