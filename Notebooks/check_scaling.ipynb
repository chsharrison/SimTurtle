# %% [raw]
# Check scaling of CMS with number of particles (one proccessor)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
npar = [32, 2304, 4464, 8064, 9504, 11664]
time = [0.5, 7.83, 11.4, 1*60+25 , 3*60+13.5, 8*60+43]

# %%
plt.plot(npar,time,'.-')

# %%
# scaling with 2 proccessors
npar = [4752, 5472, 6192, 7632, 8282, 8692, 9752]
time = [13.2, 18, 21, 32, 38, 86.4, 130]

# %%
plt.plot(npar,time,'.-')

# %%
# three proccesors
npar = [5522, 6800, 8417, 9090]
time = [19.2, 27.6, 36, 125]
plt.plot(npar,time,'.-')
